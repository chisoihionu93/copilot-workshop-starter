# %% [markdown]
# ## Q1 2024 Revenue by Product Category
#
# **Business question:** Which product categories drove the most revenue in Q1 2024?
#
# **Dataset:** orders.csv — 1,200 retail orders, January to December 2024
#
# **Key finding:** *(complete this after running the analysis)*
#
# **Built with:** GitHub Copilot in VS Code  |  **Date:**

# %%
# Load orders.csv from the track-b folder into a pandas DataFrame called df
# Print the shape (rows, columns) and show the first 10 rows

# %%
# Show the data type of each column
# Show the number of null values in each column
# Show basic statistics (min, max, mean) for order_value and quantity

# %%
# Convert the order_date column to datetime format
# Filter df to rows where order_date is in Q1 2024
# (January 1 to March 31, 2024)
# Store the result as df_q1
# Print how many rows are in df_q1

# %%
# Using df_q1, calculate total revenue by product_category
# Sum the order_value column, grouped by product_category
# Sort by total revenue descending
# Reset the index
# Store the result as revenue_by_cat
# Print all rows

# %%
# Add a new column to revenue_by_cat called 'pct_of_total'
# It should show each category's revenue as a percentage of total Q1 revenue
# Round to 1 decimal place
# Print the updated DataFrame

# %%
# Rename the columns in revenue_by_cat:
# 'product_category' -> 'Category'
# 'order_value'      -> 'Total Revenue (USD)'
# 'pct_of_total'     -> '% of Q1 Revenue'
# Print the renamed DataFrame

# %%
# Filter revenue_by_cat to the top 5 rows by Total Revenue (USD)
# Store as top5
# Print top5

# %%
# Create a horizontal bar chart using matplotlib from the top5 DataFrame
# X-axis: 'Total Revenue (USD)'
# Y-axis: 'Category' - sort bars so highest revenue is at the top
# Title: 'Clothing and Electronics Account for Over Half of Q1 Revenue'
# X-axis label: 'Total Revenue (USD)'
# Y-axis label: ''
# Bar color: #117A65
# Add value labels at the end of each bar showing revenue formatted with $ and commas
# Add a subtitle in smaller grey text: 'Top 5 categories by revenue, Q1 2024'
# Figure size: (12, 6)
# Remove the top and right chart borders (spines)
# Show the chart
